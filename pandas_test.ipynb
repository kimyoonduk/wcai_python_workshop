# %%
import pandas as pd
df = pd.read_csv('/Users/ydkim/Documents/2017_s/wcai/module5_yelp.csv')

# %%
len(df)
# Out:
# 647

# %%
df.columns
df.dtypes
# Out:
# name             object
# categories/0     object
# categories/1     object
# city             object
# review_count      int64
# state            object
# stars           float64
# Take-out           bool
# dtype: object

# %%
df.describe()
# Out:
#        review_count       stars
# count    647.000000  647.000000
# mean      23.803709    3.593509
# std       43.065615    0.927389
# min        3.000000    1.000000
# 25%        4.000000    3.000000
# 50%        9.000000    3.500000
# 75%       21.000000    4.500000
# max      463.000000    5.000000

# %%
df.head()
# Out:
#                             name     categories/0      categories/1  \
# 0  First Class Limousine Service  Hotels & Travel  Airport Shuttles
# 1          Elite Coach Limousine  Hotels & Travel  Airport Shuttles
# 2             Voyager Jet Center  Hotels & Travel          Airports
# 3                  Emil's Lounge             Bars    American (New)
# 4                      Bar Louie             Bars    American (New)
#
#              city  review_count state  stars Take-out
# 0       Homestead            12    PA    4.5    False
# 1      Pittsburgh             3    PA    2.5    False
# 2    West Mifflin             3    PA    4.5    False
# 3        Braddock            26    PA    4.5     True
# 4  West Homestead            92    PA    2.5     True

# %%
df.head(100)
# Out:
#                                 name               categories/0  \
# 0      First Class Limousine Service            Hotels & Travel
# 1              Elite Coach Limousine            Hotels & Travel
# 2                 Voyager Jet Center            Hotels & Travel
# 3                      Emil's Lounge                       Bars
# 4                          Bar Louie                       Bars
# 5                            Peanutz                       Bars
# 6             Aracri's Greentree Inn                    Italian
# 7              Alexion's Bar & Grill                       Bars
# 8                     Rocky's Lounge                       Bars
# 9                            Denny's         Breakfast & Brunch
# 10                   Dave & Buster's       Arts & Entertainment
# 11                       Rock Bottom                       Food
# 12                       TGI Fridays                       Bars
# 13            Mitchell's Fish Market                    Seafood
# ...

# %%
df["name"]
# Out:
# 0                       First Class Limousine Service
# 1                               Elite Coach Limousine
# 2                                  Voyager Jet Center
# 3                                       Emil's Lounge
# 4                                           Bar Louie
# 5                                             Peanutz
# 6                              Aracri's Greentree Inn
# 7                               Alexion's Bar & Grill
# 8                                      Rocky's Lounge
# 9                                             Denny's
# 10                                    Dave & Buster's
# 11                                        Rock Bottom
# 12                                        TGI Fridays
# 13                             Mitchell's Fish Market
# 14                                         Applebee's
# 15                                  Clark Bar & Grill
# 16                                             Huddle
# ...
