# %%
import pandas as pd

xls = pd.ExcelFile('yelp.xlsx')
df = xls.parse('yelp_data')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 600

# %%
df.shape
# Out:
# (600, 8)

# %%
df.count()
# Out:
# name            600
# category_0      600
# category_1      600
# take_out        600
# review_count    600
# stars           600
# city_id         600
# state_id        600
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'category_0', 'category_1', 'take_out', 'review_count', 'stars',
#        'city_id', 'state_id'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name             object
# category_0       object
# category_1       object
# take_out           bool
# review_count      int64
# stars           float64
# city_id           int64
# state_id          int64
# dtype: object

# %%
df.describe()
# Out:
#        review_count       stars     city_id    state_id
# count    600.000000  600.000000  600.000000  600.000000
# mean      33.771667    3.495000    9.193333    1.500000
# std       86.901895    0.955596    2.997933    0.500417
# min        3.000000    1.000000    1.000000    1.000000
# 25%        5.000000    3.000000    8.000000    1.000000
# 50%       10.000000    3.500000   10.500000    1.500000
# 75%       25.250000    4.000000   12.000000    2.000000
# max     1305.000000    5.000000   13.000000    2.000000

# %%
df.head()#defaults to 5
# Out:
#                            name   category_0       category_1 take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese     True
# 1          Discount Tire Center        Tires       Automotive    False
# 2                  Frankfurters  Restaurants         Hot Dogs     True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts    False
# 4                 Kuhn's Market         Food          Grocery    False
#
#    review_count  stars  city_id  state_id
# 0            11    2.5        1         1
# 1            24    4.5        1         1
# 2             3    4.5        1         1
# 3             6    4.0        1         1
# 4             8    3.5        1         1

# %%
df.head(100)#100 lines
# Out:
#                                               name  \
# 0                     China Sea Chinese Restaurant
# 1                             Discount Tire Center
# 2                                     Frankfurters
# 3                                Fred Dietz Floral
# 4                                    Kuhn's Market
# 5                                   Lincoln Bakery
# 6                                 Luigi's Pizzeria
# 7                       Mane Attractions Unlimited
# 8                              R & B's Pizza Place
# 9                                       Rusty Nail
# 10                                      Star Nails
# 11                                            Vivo
# 12                                   Emil's Lounge
# 13                            Grand View Golf Club
# 14                              Advance Auto Parts
# 15                           Alexion's Bar & Grill
# 16                                Alteration World
# ...

# %%
df["name"]
# Out:
# 0                           China Sea Chinese Restaurant
# 1                                   Discount Tire Center
# 2                                           Frankfurters
# 3                                      Fred Dietz Floral
# 4                                          Kuhn's Market
# 5                                         Lincoln Bakery
# 6                                       Luigi's Pizzeria
# 7                             Mane Attractions Unlimited
# 8                                    R & B's Pizza Place
# 9                                             Rusty Nail
# 10                                            Star Nails
# 11                                                  Vivo
# 12                                         Emil's Lounge
# 13                                  Grand View Golf Club
# 14                                    Advance Auto Parts
# 15                                 Alexion's Bar & Grill
# ...

# %%
atts = ["name", "city_id", "state_id"]
df[atts].head(100)
# Out:
#                                               name  city_id  state_id
# 0                     China Sea Chinese Restaurant        1         1
# 1                             Discount Tire Center        1         1
# 2                                     Frankfurters        1         1
# 3                                Fred Dietz Floral        1         1
# 4                                    Kuhn's Market        1         1
# 5                                   Lincoln Bakery        1         1
# 6                                 Luigi's Pizzeria        1         1
# 7                       Mane Attractions Unlimited        1         1
# 8                              R & B's Pizza Place        1         1
# 9                                       Rusty Nail        1         1
# 10                                      Star Nails        1         1
# 11                                            Vivo        1         1
# ...

# %%
df_cities = xls.parse('cities')
df = pd.merge(left=df, right=df_cities, how='inner', left_on='city_id', right_on='id')

# %%
df.head()
# Out:
#                            name   category_0       category_1 take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese     True
# 1          Discount Tire Center        Tires       Automotive    False
# 2                  Frankfurters  Restaurants         Hot Dogs     True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts    False
# 4                 Kuhn's Market         Food          Grocery    False
#
#    review_count  stars  city_id  state_id  id      city
# 0            11    2.5        1         1   1  Bellevue
# 1            24    4.5        1         1   1  Bellevue
# 2             3    4.5        1         1   1  Bellevue
# 3             6    4.0        1         1   1  Bellevue
# 4             8    3.5        1         1   1  Bellevue

# %%
df.shape
# Out:
# (600, 10)

# %%
df_states = xls.parse('states')
df = pd.merge(left=df, right=df_states, how='inner', left_on='state_id', right_on='id')

# %%
df.shape
# Out:
# (600, 12)

# %%
atts = ["name", "city", "state"]
df[atts].head(100)
# Out:
#                                               name           city state
# 0                     China Sea Chinese Restaurant       Bellevue    PA
# 1                             Discount Tire Center       Bellevue    PA
# 2                                     Frankfurters       Bellevue    PA
# 3                                Fred Dietz Floral       Bellevue    PA
# 4                                    Kuhn's Market       Bellevue    PA
# 5                                   Lincoln Bakery       Bellevue    PA
# 6                                 Luigi's Pizzeria       Bellevue    PA
# 7                       Mane Attractions Unlimited       Bellevue    PA
# 8                              R & B's Pizza Place       Bellevue    PA
# 9                                       Rusty Nail       Bellevue    PA
# 10                                      Star Nails       Bellevue    PA
# 11                                            Vivo       Bellevue    PA
# ...

# %%
df[2:5]
# Out:
#                 name   category_0       category_1 take_out  review_count  \
# 2       Frankfurters  Restaurants         Hot Dogs     True             3
# 3  Fred Dietz Floral     Shopping  Flowers & Gifts    False             6
# 4      Kuhn's Market         Food          Grocery    False             8
#
#    stars  city_id  state_id  id_x      city  id_y state
# 2    4.5        1         1     1  Bellevue     1    PA
# 3    4.0        1         1     1  Bellevue     1    PA
# 4    3.5        1         1     1  Bellevue     1    PA

# %%
df[:10]
# Out:
#                            name   category_0              category_1 take_out  \
# 0  China Sea Chinese Restaurant  Restaurants                 Chinese     True
# 1          Discount Tire Center        Tires              Automotive    False
# 2                  Frankfurters  Restaurants                Hot Dogs     True
# 3             Fred Dietz Floral     Shopping         Flowers & Gifts    False
# 4                 Kuhn's Market         Food                 Grocery    False
# 5                Lincoln Bakery         Food                Bakeries     True
# 6              Luigi's Pizzeria  Restaurants                   Pizza     True
# 7    Mane Attractions Unlimited  Hair Salons           Beauty & Spas    False
# 8           R & B's Pizza Place  Restaurants                   Pizza     True
# 9                    Rusty Nail  Restaurants  American (Traditional)     True
#
#    review_count  stars  city_id  state_id  id_x      city  id_y state
# ...

# %%
df[-4:]
# Out:
#                      name      category_0                       category_1  \
# 596          SA Recycling  Local Services                 Recycling Center
# 597       Jack In the Box     Restaurants                        Fast Food
# 598  Custom Hearth & Door        Shopping  Heating & Air Conditioning/HVAC
# 599      A Sunrise Towing      Automotive                           Towing
#
#     take_out  review_count  stars  city_id  state_id  id_x             city  \
# 596    False             3    1.5       13         2    13  North Las Vegas
# 597     True            12    3.0       13         2    13  North Las Vegas
# 598    False             9    4.0       13         2    13  North Las Vegas
# 599    False             4    1.0       13         2    13  North Las Vegas
#
#      id_y state
# 596     2    NV
# 597     2    NV
# 598     2    NV
# 599     2    NV

# %%
df[-1:]["name"]
# Out:
# 599    A Sunrise Towing
# Name: name, dtype: object

# %%
type(df[:10])
# Out:
# pandas.core.frame.DataFrame

# %%
df[100:200]["name"]
# Out:
# 100                                   Au Bon Pain Co
# 101                 Bado's Pizza Grill and Ale House
# 102                             Bastone Auto Service
# 103                        Bellisario's Pizza Palace
# 104           Benedum Center for the Performing Arts
# 105                                     Beto's Pizza
# 106                                Better-Maid Donut
# 107                                      Big Burrito
# 108                         Billy's Troy Hill Bistro
# 109                        Boehmer Heating & Cooling
# 110                                       BreadWorks
# 111                              Broadway Auto Parts
# 112                                  Brown Bag Delis
# 113                                Bruegger's Bagels
# 114                                    Buffalo Blues
# 115                                 Buon Giorno Cafe
# 116                                    Cain's Saloon
# 117                    Calabria's Italian Restaurant
# ...

# %%
type(df[["name", "city"]])
# Out:
# pandas.core.frame.DataFrame

# %%
stars = df["stars"]
stars
# Out:
# 0      2.5
# 1      4.5
# 2      4.5
# 3      4.0
# 4      3.5
# 5      4.0
# 6      4.0
# 7      3.0
# 8      4.0
# 9      3.5
# 10     2.5
# 11     5.0
# 12     4.5
# 13     5.0
# 14     3.5
# 15     4.0
# 16     4.5
# 17     3.0
# 18     4.0
# 19     4.5
# 20     2.5
# 21     3.5
# 22     2.5
# 23     4.0
# 24     4.5
# 25     3.0
# 26     3.5
# 27     3.5
# 28     3.5
# 29     3.5
#       ...
# 570    4.0
# 571    1.5
# 572    2.0
# 573    3.0
# 574    1.5
# 575    1.5
# 576    4.5
# 577    4.5
# 578    3.5
# 579    2.5
# 580    5.0
# 581    3.5
# 582    2.0
# 583    3.5
# 584    3.0
# 585    4.5
# 586    4.0
# 587    2.0
# 588    3.5
# 589    1.5
# 590    1.5
# 591    3.0
# 592    3.0
# 593    3.5
# 594    4.5
# 595    2.5
# 596    1.5
# 597    3.0
# 598    4.0
# 599    1.0
# Name: stars, dtype: float64

# %%
type(stars)
# Out:
# pandas.core.series.Series

# %%
pitts = df["city"] == "Pittsburgh"
type(pitts)
print(pitts)
df[pitts]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# 583    False
# 584    False
# 585    False
# 586    False
# 587    False
# 588    False
# 589    False
# 590    False
# 591    False
# 592    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Name: city, dtype: bool
#                                                name  \
# ...

# %%
rest = df["name"] == "The Dragon Chinese Cuisine"
bus = df[rest]["take_out"]
bus
bus.iloc[0]
#type(df[rest|rest2][["name","take_out"]])
#df[rest][["name","take_out"]]
#df[rest|rest2][["name","take_out"]][0:1].iloc[0].iloc[0]

#type(df[rest|rest2][["name","take_out"]][0:1])

#type(df[rest]["take_out"])
#df[rest][["name", "take_out"]].iloc[0][0]

#dir(df[rest]["take_out"])
#print("yes", df[rest]["take_out"])
# Out:
# True

# %%
last_index = len(df) - 1
last_business = df[last_index:] #returns the last row
print(last_business["review_count"])
# Out:
# 599    4
# Name: review_count, dtype: int64

# %%
df[-1:]
# Out:
#                  name  category_0 category_1 take_out  review_count  stars  \
# 599  A Sunrise Towing  Automotive     Towing    False             4    1.0
#
#      city_id  state_id  id_x             city  id_y state
# 599       13         2    13  North Las Vegas     2    NV

# %%
df[-1:]['name'].iloc[0]
# Out:
# 'A Sunrise Towing'

# %%
import random

lv = df["city"] == "Las Vegas"
cat_0_bars = df["category_0"] == "Dive Bars"
cat_1_bars = df["category_1"] == "Dive Bars"
divebars_lv = df[lv & (cat_0_bars | cat_0_bars)]
print("There are", len(divebars_lv), "dive bar(s)in LV")

stars = divebars_lv["stars"] >= 4.0
divebars_4rating_lv = divebars_lv[stars]
rand_int = random.randint(0, len(divebars_4rating_lv) - 1)
rand_divebar = divebars_4rating_lv[rand_int:rand_int + 1]
print("Here's one with a", rand_divebar["stars"].iloc[0], "rating")
rand_divebar[["name","stars","review_count"]]
# Out:
# There are 3 dive bar(s)in LV
# Here's one with a 4.0 rating
#              name  stars  review_count
# 453  Moon Doggies    4.0            85

# %%
cat_0_bars = df["category_0"] == "Bars"
cat_1_bars = df["category_1"] == "Bars"
df[cat_0_bars | cat_1_bars]
# Out:
#                                  name   category_0              category_1  \
# 12                      Emil's Lounge         Bars          American (New)
# 15              Alexion's Bar & Grill         Bars  American (Traditional)
# 32                     Rocky's Lounge         Bars  American (Traditional)
# 42             Duke's Upper Deck Cafe         Pubs                    Bars
# 62            Randy's Beer Barrel Pub         Pubs                    Bars
# 70                        TGI Fridays         Bars  American (Traditional)
# 77                         Applebee's         Bars  American (Traditional)
# 101  Bado's Pizza Grill and Ale House      Italian                    Bars
# 114                     Buffalo Blues  Restaurants                    Bars
# 119                      Cappy's Cafe         Bars  American (Traditional)
# 138                       Doc's Place         Bars                   Pizza
# ...

# %%
carnegie = df["city"] == "Carnegie"
df[carnegie]
# Out:
#                                              name  \
# 14                             Advance Auto Parts
# 15                          Alexion's Bar & Grill
# 16                               Alteration World
# 17                                       Amerifit
# 18                   Barb's Country Junction Cafe
# 19                          Carnegie Free Library
# 20                     Don Don Chinese Restaurant
# 21  Extended Stay America - Pittsburgh - Carnegie
# 22                    Flynn's Tire & Auto Service
# 23               Forsythe Miniature Golf & Snacks
# 24                                      Gab & Eat
# 25                                 Heidelberg B P
# 26                        Kings Family Restaurant
# 27                         Knorr's Sunoco Service
# 28                             Paddy's Pour House
# 29                                       Papa J's
# 30                     Porto Fino Pizzaria & Gyro
# 31                      Quaker State Construction
# ...

# %%
cat_0 = df["category_0"].isin(["Bars", "Restaurants"])
cat_1 = df["category_1"].isin(["Bars", "Restaurants"])
carnegie = df["city"] == "Carnegie"
df[(cat_0 | cat_1) & carnegie]
# Out:
#                             name   category_0              category_1  \
# 15         Alexion's Bar & Grill         Bars  American (Traditional)
# 18  Barb's Country Junction Cafe  Restaurants                   Cafes
# 20    Don Don Chinese Restaurant  Restaurants                 Chinese
# 29                      Papa J's  Restaurants                 Italian
# 30    Porto Fino Pizzaria & Gyro  Restaurants                   Pizza
# 32                Rocky's Lounge         Bars  American (Traditional)
#
#    take_out  review_count  stars  city_id  state_id  id_x      city  id_y  \
# 15     True            23    4.0        3         1     3  Carnegie     1
# 18     True             9    4.0        3         1     3  Carnegie     1
# 20     True            10    2.5        3         1     3  Carnegie     1
# 29     True            81    3.5        3         1     3  Carnegie     1
# 30    False             4    2.5        3         1     3  Carnegie     1
# ...

# %%
cat_0 = df["category_0"].str.contains("Nail Salons")
cat_1 = df["category_1"].str.contains("Nail Salons")
henderson = df["city"] == "Henderson"
df[(cat_0 | cat_1) & henderson]["review_count"].sum()
# Out:
# 158

# %%
cat_0 = df["category_0"] == 'Auto Repair'
cat_1 = df["category_1"] == 'Auto Repair'
pitts = df["city"] == 'Pittsburgh'
#df[(cat_0 | cat_1) & pitts]
df[(cat_0 | cat_1) & pitts]["stars"].mean()
# Out:
# 4.5

# %%
cat_0 = df["category_0"].str.contains("Auto Repair")
cat_1 = df["category_1"] .str.contains("Auto Repair")
pitts = df["city"] == 'Pittsburgh'
df[(cat_0 | cat_1) & pitts]
# Out:
#                             name   category_0  category_1 take_out  \
# 95           Aamco Transmissions  Auto Repair  Automotive    False
# 102         Bastone Auto Service  Auto Repair  Automotive    False
# 111          Broadway Auto Parts  Auto Repair  Automotive    False
# 137  Dependable Brakes & Exhaust  Auto Repair  Automotive    False
# 245           Ruffing Automotive  Auto Repair  Automotive    False
# 283          Walter's Automotive  Auto Repair  Automotive    False
#
#      review_count  stars  city_id  state_id  id_x        city  id_y state
# 95             21    4.5        8         1     8  Pittsburgh     1    PA
# 102            20    4.0        8         1     8  Pittsburgh     1    PA
# 111             4    5.0        8         1     8  Pittsburgh     1    PA
# 137             4    5.0        8         1     8  Pittsburgh     1    PA
# 245             3    3.5        8         1     8  Pittsburgh     1    PA
# ...

# %%
df.groupby(['category_0']).sum()
# Out:
#                               take_out  review_count  stars  city_id  \
# category_0
# Active Life                        0.0           188   39.0       83
# Acupuncture                        0.0             3    5.0        8
# Adult Entertainment                0.0             4    2.5        5
# American (New)                     1.0            79    6.5       19
# American (Traditional)             3.0            92   11.0       23
# Animal Shelters                    0.0            43    4.0        8
# Arts & Entertainment               1.0           192   51.0      122
# Auto Repair                        0.0           426   58.5      136
# Automotive                         0.0           346   54.0      178
# Banks & Credit Unions              0.0             7    3.5       12
# Barbers                            0.0            35    9.0       16
# Bars                              12.0           512   56.0      122
# ...

# %%
df['city'].value_counts()
# Out:
# Pittsburgh         193
# Las Vegas          133
# Henderson          130
# Homestead           41
# North Las Vegas     37
# Carnegie            22
# Bellevue            12
# Mc Kees Rocks       10
# West Mifflin         9
# Mount Lebanon        4
# Munhall              4
# West Homestead       3
# Braddock             2
# Name: city, dtype: int64

# %%
#df['city'].value_counts()
df['category_0'].nunique()
# Out:
# 89

# %%
df["city"].unique()
# Out:
# array(['Bellevue', 'Braddock', 'Carnegie', 'Homestead', 'Mc Kees Rocks',
#        'Mount Lebanon', 'Munhall', 'Pittsburgh', 'West Homestead',
#        'West Mifflin', 'Henderson', 'Las Vegas', 'North Las Vegas'], dtype=object)

# %%
df["rating"] = df["stars"] * 2
df.head(100)
# Out:
#                                               name  \
# 0                     China Sea Chinese Restaurant
# 1                             Discount Tire Center
# 2                                     Frankfurters
# 3                                Fred Dietz Floral
# 4                                    Kuhn's Market
# 5                                   Lincoln Bakery
# 6                                 Luigi's Pizzeria
# 7                       Mane Attractions Unlimited
# 8                              R & B's Pizza Place
# 9                                       Rusty Nail
# 10                                      Star Nails
# 11                                            Vivo
# 12                                   Emil's Lounge
# 13                            Grand View Golf Club
# 14                              Advance Auto Parts
# 15                           Alexion's Bar & Grill
# 16                                Alteration World
# ...

# %%
df["categories"] = df["category_0"].str.cat(df["category_1"], sep=',')
#df["categories"] = ','.join([df["category_0"].get_value(0), df["category_1"].get_value(0)])
df.head(100)
# Out:
#                                               name  \
# 0                     China Sea Chinese Restaurant
# 1                             Discount Tire Center
# 2                                     Frankfurters
# 3                                Fred Dietz Floral
# 4                                    Kuhn's Market
# 5                                   Lincoln Bakery
# 6                                 Luigi's Pizzeria
# 7                       Mane Attractions Unlimited
# 8                              R & B's Pizza Place
# 9                                       Rusty Nail
# 10                                      Star Nails
# 11                                            Vivo
# 12                                   Emil's Lounge
# 13                            Grand View Golf Club
# 14                              Advance Auto Parts
# 15                           Alexion's Bar & Grill
# 16                                Alteration World
# ...

# %%
df[df["categories"].str.contains("Pizza")]
# Out:
#                                    name              category_0   category_1  \
# 6                      Luigi's Pizzeria             Restaurants        Pizza
# 8                   R & B's Pizza Place             Restaurants        Pizza
# 30           Porto Fino Pizzaria & Gyro             Restaurants        Pizza
# 48                Homestead Capri Pizza                 Italian        Pizza
# 49                Italian Village Pizza             Restaurants        Pizza
# 73                 Uno Pizzeria & Grill  American (Traditional)        Pizza
# 83            Pasquarelli's Pizza House             Restaurants        Pizza
# 94                    The Pizza Company             Restaurants        Pizza
# 103           Bellisario's Pizza Palace                 Italian        Pizza
# 105                        Beto's Pizza             Restaurants        Pizza
# 117       Calabria's Italian Restaurant             Restaurants        Pizza
# ...

# %%
#pointless, but shows multiplying every PlayCount by a number, updating the df, then prinitng head
df["Price"] *= 100000
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity       Price     Status
# 0          CPU         1  3000000000  presented
# 1     Software         1  1000000000  presented
# 2  Maintenance         2   500000000    pending
# 3          CPU         1  3500000000   declined
# 4          CPU         2  6500000000        won

# %%
#add new column
def convert_to_rating(x):
    return (str(x * 2) + " out of 10")

df["rating"] = df["stars"].apply(convert_to_rating)
df.head(100)
# Out:
#                                               name  \
# 0                     China Sea Chinese Restaurant
# 1                             Discount Tire Center
# 2                                     Frankfurters
# 3                                Fred Dietz Floral
# 4                                    Kuhn's Market
# 5                                   Lincoln Bakery
# 6                                 Luigi's Pizzeria
# 7                       Mane Attractions Unlimited
# 8                              R & B's Pizza Place
# 9                                       Rusty Nail
# 10                                      Star Nails
# 11                                            Vivo
# 12                                   Emil's Lounge
# 13                            Grand View Golf Club
# 14                              Advance Auto Parts
# 15                           Alexion's Bar & Grill
# 16                                Alteration World
# ...

# %%
#add them up!
df[is_pending]["Amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-231799bbbd37> in <module>()
#       1 #add them up!
# ----> 2 df[is_pending]["Amount"].sum()
#
# NameError: name 'is_pending' is not defined

# %%
df.groupby(['city']).groups.keys()
# Out:
# dict_keys(['Henderson', 'Las Vegas', 'West Mifflin', 'Pittsburgh', 'Munhall', 'Mount Lebanon', 'Mc Kees Rocks', 'Carnegie', 'Braddock', 'West Homestead', 'North Las Vegas', 'Bellevue', 'Homestead'])

# %%
#group by 2 columns
df.groupby(['city', 'state']).groups.keys()
# Out:
# dict_keys([('Munhall', 'PA'), ('Pittsburgh', 'PA'), ('Bellevue', 'PA'), ('Henderson', 'NV'), ('North Las Vegas', 'NV'), ('Las Vegas', 'NV'), ('Mc Kees Rocks', 'PA'), ('Homestead', 'PA'), ('Mount Lebanon', 'PA'), ('Carnegie', 'PA'), ('Braddock', 'PA'), ('West Homestead', 'PA'), ('West Mifflin', 'PA')])

# %%
#df.groupby(['city']).groups['Las Vegas']
len(df.groupby(['city']).groups['Las Vegas'])
# Out:
# 133

# %%
import numpy as np

df.groupby(['city']).agg([np.sum, np.mean, np.std])["stars"]
# Out:
#                    sum      mean       std
# city
# Bellevue          45.0  3.750000  0.783349
# Braddock           9.5  4.750000  0.353553
# Carnegie          76.0  3.454545  0.688495
# Henderson        444.5  3.419231  0.906060
# Homestead        134.5  3.280488  0.837024
# Las Vegas        452.0  3.398496  1.042214
# Mc Kees Rocks     37.0  3.700000  0.856349
# Mount Lebanon     12.5  3.125000  1.108678
# Munhall           12.0  3.000000  0.816497
# North Las Vegas  112.0  3.027027  1.073325
# Pittsburgh       718.0  3.720207  0.902517
# West Homestead    10.0  3.333333  1.040833
# West Mifflin      34.0  3.777778  1.227577

# %%
pivot_city = pd.pivot_table(df,index=["city"])
pivot_city
#type(pivot_city)
# Out:
# pandas.core.frame.DataFrame

# %%
pivot_state_city = pd.pivot_table(df,index=["state", "city"])
pivot_state_city
# Out:
#                        city_id  id_x  id_y  review_count     stars  state_id  \
# state city
# NV    Henderson           11.0  11.0   2.0     33.323077  3.419231       2.0
#       Las Vegas           12.0  12.0   2.0     54.330827  3.398496       2.0
#       North Las Vegas     13.0  13.0   2.0     10.756757  3.027027       2.0
# PA    Bellevue             1.0   1.0   1.0     13.166667  3.750000       1.0
#       Braddock             2.0   2.0   1.0     14.500000  4.750000       1.0
#       Carnegie             3.0   3.0   1.0     13.590909  3.454545       1.0
#       Homestead            4.0   4.0   1.0     23.243902  3.280488       1.0
#       Mc Kees Rocks        5.0   5.0   1.0     10.700000  3.700000       1.0
#       Mount Lebanon        6.0   6.0   1.0      6.250000  3.125000       1.0
#       Munhall              7.0   7.0   1.0     22.750000  3.000000       1.0
#       Pittsburgh           8.0   8.0   1.0     33.523316  3.720207       1.0
# ...

# %%
pivot_state_take = pd.pivot_table(df,index=["state", "take_out"])
pivot_state_take
# Out:
#                   city_id       id_x  id_y  review_count     stars  state_id
# state take_out
# NV    False     11.698276  11.698276   2.0     16.900862  3.409483       2.0
#       True      11.661765  11.661765   2.0    118.161765  3.198529       2.0
# PA    False      6.643678   6.643678   1.0     11.580460  3.695402       1.0
#       True       6.769841   6.769841   1.0     49.936508  3.535714       1.0

# %%
rest = df["category_0"].isin(["Bars", "Restaurants"])
df_rest = df[rest]

pivot_state_cat = pd.pivot_table(df_rest,index=["state", "city", "category_0"])
pivot_state_cat[["review_count", "stars"]]
# Out:
#                                    review_count     stars
# state city            category_0
# NV    Henderson       Bars           171.000000  3.000000
#                       Restaurants    102.454545  3.181818
#       Las Vegas       Bars            15.500000  4.000000
#                       Restaurants    221.153846  3.153846
#       North Las Vegas Bars             7.000000  3.500000
#                       Restaurants     12.000000  3.000000
# PA    Bellevue        Restaurants     14.000000  3.916667
#       Braddock        Bars            26.000000  4.500000
#       Carnegie        Bars            16.500000  4.000000
#                       Restaurants     26.000000  3.125000
#       Homestead       Bars            23.000000  2.500000
#                       Restaurants      6.000000  2.500000
#       Mc Kees Rocks   Bars             9.000000  3.500000
#                       Restaurants      7.333333  3.333333
#       Munhall         Restaurants      9.500000  3.500000
# ...

# %%
#pivot table
import numpy as np
pivot_agg = pd.pivot_table(df,index=["state", "city"], values=["review_count"], aggfunc=[np.sum])
pivot_agg
# Out:
#                                sum
#                       review_count
# state city
# NV    Henderson               4332
#       Las Vegas               7226
#       North Las Vegas          398
# PA    Bellevue                 158
#       Braddock                  29
#       Carnegie                 299
#       Homestead                953
#       Mc Kees Rocks            107
#       Mount Lebanon             25
#       Munhall                   91
#       Pittsburgh              6470
#       West Homestead           124
#       West Mifflin              51

# %%
pivot_agg2 = pd.pivot_table(df,index=["state", "city"], values=["review_count"], columns=["take_out"], aggfunc=[np.sum])
pivot_agg2
# Out:
#                                sum
#                       review_count
# take_out                     False True
# state city
# NV    Henderson               2009  2323
#       Las Vegas               1619  5607
#       North Las Vegas          293   105
# PA    Bellevue                  52   106
#       Braddock                   3    26
#       Carnegie                  74   225
#       Homestead                323   630
#       Mc Kees Rocks             48    59
#       Mount Lebanon             13    12
#       Munhall                   12    79
#       Pittsburgh              1447  5023
#       West Homestead             7   117
#       West Mifflin              36    15

# %%
pivot_agg3 = pd.pivot_table(df,index=["state", "city"], values=["review_count", "stars"], columns=["take_out"], aggfunc={"review_count":np.sum, "stars":np.mean})
pivot_agg3
# Out:
#                       review_count             stars
# take_out                     False   True      False     True
# state city
# NV    Henderson             2009.0  2323.0  3.469697  3.258065
#       Las Vegas             1619.0  5607.0  3.423077  3.310345
#       North Las Vegas        293.0   105.0  3.155172  2.562500
# PA    Bellevue                52.0   106.0  3.750000  3.750000
#       Braddock                 3.0    26.0  5.000000  4.500000
#       Carnegie                74.0   225.0  3.269231  3.722222
#       Homestead              323.0   630.0  3.416667  2.909091
#       Mc Kees Rocks           48.0    59.0  3.666667  3.714286
#       Mount Lebanon           13.0    12.0  3.000000  3.500000
#       Munhall                 12.0    79.0  3.000000  3.000000
#       Pittsburgh            1447.0  5023.0  3.836364  3.566265
#       West Homestead           7.0   117.0  4.500000  2.750000
#       West Mifflin            36.0    15.0  3.500000  4.333333

# %%
pivot_agg3.query('city == ["Las Vegas"]')
# Out:
#                 review_count             stars
# take_out               False   True      False     True
# state city
# NV    Las Vegas       1619.0  5607.0  3.423077  3.310345

# %%
#reset index
#reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-e3da6e296f2d> in <module>()
#       1 #reset index
# ----> 2 reset_index()
#
# NameError: name 'reset_index' is not defined

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df_pitt = df[df["city"] == 'Pittsburgh']
df_vegas = df[df["city"] == 'Las Vegas']
df_vegas
# Out:
#                                     name            category_0  \
# 430                Reliable Tax Services    Financial Services
# 431        Paradise Electro Stimulations              Shopping
# 432                           The Studio              Shopping
# 433                         Boomer's Bar                  Bars
# 434                         Omelet House    Breakfast & Brunch
# 435                   Armstrong Emporium              Shopping
# 436                  A-1 Vacuum & Sewing        Local Services
# 437                        Art encounter  Arts & Entertainment
# 438             Contemporary Arts Center  Arts & Entertainment
# 439        Palace Station Hotel & Casino       Hotels & Travel
# 440   Southern Nevada Museum of Fine Art               Museums
# 441                     Kao Auto Styling            Automotive
# 442                  Charleston Car Wash              Car Wash
# 443                 Charlie's Car Repair           Auto Repair
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

df_pitt = df[df["city"] == 'Pittsburgh']
df_vegas = df[df["city"] == 'Las Vegas']

series_vegas = df_vegas["stars"]
series_pitt = df_pitt["stars"]

plt.hist(series_pitt, alpha=0.3, color='yellow', label='Pittsburgh', normed='True')
plt.hist(series_vegas, alpha=0.3, color='red', label='Vegas', normed='True')

plt.xlabel('Rating')
plt.ylabel('Proportion')

plt.legend(loc='best')
plt.title("Review distribution of Pittsburgh and Las Vegas")


plt.show()

# %%
plt.hist([list_pitt,list_vegas], alpha=0.7, color=['red','blue'], label=['Pittsburgh','Las Vegas'], normed='True')

plt.xlabel('Rating')
plt.ylabel('Proportion')


plt.title("Review distribution of Pittsburgh and Las Vegas")
plt.legend(loc='best')



plt.show()

# %%
df.groupby(['city']).agg([np.mean, np.std])["stars"].query('city == ["Pittsburgh", "Las Vegas"]')
# Out:
#                 mean       std
# city
# Las Vegas   3.398496  1.042214
# Pittsburgh  3.720207  0.902517

# %%
df_health = df[df["category_0"] == 'Health & Medical']
df_fast = df[df["category_0"] == 'Fast Food']
df_brunch = df[df["category_0"] == 'Breakfast & Brunch']



plt.scatter(df_health['stars'],df_health['review_count'],
            # marker
            marker='o',
            # color
            color='r',
            # alpha (tranparency)
            alpha=0.7,
            # size
            s = 124,
            # label
            label=['Health & Medical'])

plt.scatter(df_fast['stars'],df_fast['review_count'],
            marker='h',
            color='b',
            s = 124,
            label=['Fast Food'])

plt.scatter(df_brunch['stars'],df_brunch['review_count'],
            marker='^',
            color='g',
            alpha=0.7,
            s = 124,
            label=['Breakfast & Brunch'])


# axes = plt.gca()
# axes.set_yscale('log')

plt.xlabel('Rating')
plt.ylabel('Review Count')

plt.legend(loc='upper left')

plt.show()

# %%
df_health = df[df["category_0"] == 'Health & Medical']
df_fast = df[df["category_0"] == 'Fast Food']
df_brunch = df[df["category_0"] == 'Breakfast & Brunch']



plt.scatter(df_health['stars'],df_health['review_count'],
            # marker
            marker='o',
            # color
            color='r',
            # alpha (tranparency)
            alpha=0.7,
            # size
            s = 124,
            # label
            label=['Health & Medical'])

plt.scatter(df_fast['stars'],df_fast['review_count'],
            marker='h',
            color='b',
            s = 124,
            label=['Fast Food'])

plt.scatter(df_brunch['stars'],df_brunch['review_count'],
            marker='^',
            color='g',
            alpha=0.7,
            s = 124,
            label=['Breakfast & Brunch'])


axes = plt.gca()
axes.set_yscale('log')

plt.xlabel('Rating')
plt.ylabel('Review Count')

plt.legend(loc='upper left')

plt.show()

# %%
pivot_cat = pd.pivot_table(df,index=["category_0"], values=["review_count", "stars"], aggfunc={"review_count":[np.sum, np.mean, np.std, len], "stars":[np.mean, np.std]})
pivot_cat


pivot_cat_filtered = pivot_cat.query('category_0 == ["Health & Medical", "Fast Food", "Breakfast & Brunch"]')
pivot_cat_filtered
# Out:
#                    review_count                                   stars  \
#                             len        mean         std   sum      mean
# category_0
# Breakfast & Brunch           10  190.700000  206.175249  1907  3.700000
# Fast Food                    12   18.166667   26.267274   218  2.625000
# Health & Medical             17    8.294118   11.162239   141  4.088235
#
#
#                          std
# category_0
# Breakfast & Brunch  0.752773
# Fast Food           0.742386
# Health & Medical    1.135166

# %%
#regressions
from sklearn import cross_validation
from sklearn.linear_model import LinearRegression

model = LinearRegression()

feature = df[df.columns[:-1]]
target = df["MEDV"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/brandonkrakowsky/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'MEDV'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f82d18c62044> in <module>()
# ...

# %%
scores = cross_validation.cross_val_score(
    model,
    feature,
    target,
    cv=5
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-5b666a15cbfe> in <module>()
#       2     model,
#       3     feature,
# ----> 4     target,
#       5     cv=5
#       6 )
#
# NameError: name 'target' is not defined

# %%
#next steps

#Shore up your python (10-30hours) - Project Euler (http://pandas.pydata.org/pandas-docs/stable/)
#Tool around with pandas (20-40hours) - pandas documentation, tutorials
#Get better at analytics/sciecne workflow - Gallery of Interesting Python Notebooks (https://github.com/IPython/IPython/wiki/A-gallery-of-interesting-IPython-Notebooks)
#Practice on data (company, competition): Kaggle.com
# Out:
#   File "<ipython-input-41-9222007f97fc>", line 2
#     Shore up your python (10-30hours) - Project Euler (http://pandas.pydata.org/pandas-docs/stable/)
#            ^
# SyntaxError: invalid syntax

# %%
# %ls
# Out:
# Module 4.ipynb               read_local_csv_pandas.ipynb
# classic-rock-song-list.csv   read_remote_csv.py
# read_local_csv.py            read_remote_csv_pandas.py
